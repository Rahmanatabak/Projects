# %% [markdown]
# # Exploratory Data Analysis for Automobile Dataset Using Python
#
#
# ## International School of AI and Data Science (INSAID)

# %% [markdown]
# - **Mentor     : Mr. Suchit Majundar**
# - **Analyzed By: Rahman Atabak**
# - **Batch      : 19 September 2019**

# %% [markdown]
# ### Table of Content
# - 1. [Introducton](#section1)</br>
# - 2. [Problem Statement](#section2)</br>
# - 3. [Research Questions](#section3)</br>
# - 4. [Package Installation](#section4)</br>
# - 5. [Import Packages](#section5)</br>
# - 6. [Loading the Data](#section5)</br>
# - 7. [Data Descreption](#section7)</br>
# - 8. [Pandas Profiling befor Data Processing](#section8)</br>
# - 9. [Data Processing](#section9)</br>
# - 10. [Pandas Profiling after Data Processing](#section10)</br>
# - 11. [Univariat Analysis](#section11)</br>
# - 12. [Bivariate Analysis](#section12)</br>
# - 13. [Multivariate Analysis](#section13)</br>
# - 14. [Conclusion](#section14)</br>
# - 15. [Actionable Insights](#section15)</br>

# %% [markdown]
# <a id=section1></a>
# #### 1. Introduction
# In this project, I will be explaining univariate, bivariate and multivariate analysis of Automoblie dataset which is given by International School of AI and Data Science (INSAID). This dataset consisting of 205 observations(rows) and 26 variables(columns). Out of 26 variables, 24 variables are properties of Autos, one is insurance risk rating which is ad dependent variable and one is normallizes losses whih is continuous and measured comparatively. 24 variables which form the characteristics of autos,  10 variables are categorical, 14 variables are continuous.
# Before going through analysis step, some required steps have been conducted. These steps include pre-profilin, processing and post-profiling the data. Pre-profiling all irregularities and invalid values have been identified, in processing step, the dataset cleaned up from invalid values and finally, post-profiling again go through each variable one by one to check whether invalid values are there. After conducting these steps, now the dataset are ready for analysis. Firstly, univariate analysis conducted to determine the frequency distribution of some inmportant characteristics of autos. sencondly, bivariate analysis is done which discovered the relationship between two properties of autos. In this step, maximum possible efforts put on identifying most of pair charactersitics having relationship. Finally, univariate analysis conducted to determine the relationship between more than two variables.
# At the end of this project the conlusion and actionable insights are proposed.

# %% [markdown]
# <a id=section2></a>
# #### 2. Problem Statement
# Automobile industry is one of the most prominant and growing industry. When it came to existence, having an auto was somehow like a dream and regarded as a luxury good but gradually, it became a common good. Nowadays in developing countries, having an auto is a part of basic neccessities. Alot of companies are manufacturing autos with different characteristics, and these characteristics differentiate the price of one auto from another.
# Autos have different properties and customers have also different behaviors. Some customers like to buy Toyota brand and some Mersides, some customers buy four wheel drive whereas some customers like to buy rear or front wheels drive, some customers prefer low price autos but some customers like to buy expensive autos and so on. Since customer behaviors are different, differnt characteristics of autos cosidered as criteria for buying autos. The problem is which characteristics are more important interms of selling autos.In other words, based on which properties of autos sellers sale autos more.
# In response to this problem, this project investigates important characteristics for making decision of selling and buying autos.

# %% [markdown]
# <a id=section3></a>
# #### 3. Research Questions
# To acheive the project goal, there are some questions that should ber answered properly. These questions are broken down into two categories namely main question and sub-questions.
# - **A. Main Question:**
#   - Which properties are important criterias for selling autos?
# - **B. Important Sub-questions-**In order to answer the main question, we need to propound some other questions which called sub-questions. These questions are as follows:
#   - 1 How much autos are risky and safe in respec to their prices:
#   - 2 How much is the normalized losses of autos compared to each other?
#   - 3 Which brands have the best selling rate?
#   - 4 Which fuel type are prefered by customers more?
#   - 5 Are number of doors important for customers and how?
#   - 6 Which type of body is most prefered?
#   - 7 Which drive wheels category of autos are in the top?
#   - 8 How much engine location is important?
#   - 9 Which autos are most desirable for buyers on the basis of number of cylinders?
#   - 10 Which autos are most desirable for buyers on the basis of fuel type?
#   - 11 How are the relationship between categorical characteristics and continuous characteristics of autos?
#   - 12 How are the relationship between categorical characteristics of autos?
#   - 13 How are the relationship between continuous characteristics of autos?

# %% [markdown]
# <a id=section4></a>
# #### 4. Package Installation
# To complete the project, we need differnt packages to execute codes properely. Since there are numerious packages available in python and are used for different purposes, we only install the packages which are highly required in this project. These packages include Numpy, Pandas, seabon, Matplotlib, plotly and Pandas profiling. Here are some short definition as follows:
#
# - **Numpy:** NumPy is the fundamental package for scientific computing in Python. It is a Python library that provides a multidimensional array object, various derived objects (such as masked arrays and matrices), and an assortment of routines for fast operations on arrays, including mathematical, logical, shape manipulation, sorting, selecting, I/O, discrete Fourier transforms, basic linear algebra, basic statistical operations, random simulation and much more.
# - **Pandas:** Pandas is an open-source, BSD-licensed Python library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language. Python with Pandas is used in a wide range of fields including academic and commercial domains including finance, economics, Statistics, analytics, etc. In this tutorial, we will learn the various features of Python Pandas and how to use them in practice.
# - **Seaborn:**Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
# - **Matplotlib:** Matplotlib is an amazing visualization library in Python for 2D plots of arrays. Matplotlib is a multi-platform data visualization library built on NumPy arrays and designed to work with the broader SciPy stack. It was introduced by John Hunter in the year 2002. One of the greatest benefits of visualization is that it allows us visual access to huge amounts of data in easily digestible visuals. Matplotlib consists of several plots like line, bar, scatter, histogram etc.
# - **Pandas-Profiling:** For a lot of us, EDA may simply mean going deep into the data and finding some initial patterns and trends within the underlying data. It may also mean establishing correlations between variables to curate some interesting insights.
# However, one thing that we as data analytics practioners cannot afford to overlook, which can potentially turn our data munging aspirations into an awry nightmare, is data hygiene or data quality. Therefore, in my opinion, data quality, description, shape, patterns, and relationships completes the EDA cycle.

# %%
#!pip install numpy --upgrade
#!pip install pandas --upgrade
#!pip install seabor --upgrade
#!pip install matplotlib --upgrade
#!pip install plotly --upgrade
#!pip install pandas-profiling --upgrade

# %%
#plt.style.use("classic")
plt.style.use("seaborn-white")#make white the grid of the platform.
#plt.style.use("seaborn-whitegrid")
#plt.style.use("seaborn-white")
#plt.style.use("ggplot")

# %% [markdown]
# <a id=section5></a>
# #### 5. Import Packages
# We need some packages for the whole project work, importing in the first step of project prevent from importing them repeatedly. These packages are importde as follows:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import pandas_profiling 
pd.set_option("display.max_columns", None)   #To display all columns of dataset
pd.set_option("display.max_rows", None)      #To display all rows of all dataset
import warnings
# %matplotlib inline

# %% [markdown]
# <a id=section6></a>
# #### 6. Loading the Dataset
# The dataset that I will be working on it is available on [link](https://github.com/insaid2018/Term-1/blob/master/Data/Projects/Automobile_data.csv) for project work so, it can be loaded through online. Since I don't have access to internet connection properly, downloaded it in a local file and then read it through its path.

# %%
Am_df = pd.read_csv(r"C:\Users\ZeytoonCo\Desktop\Automobile_data.csv").head()
Am_df
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %% [markdown]
# <a id=section7></a>
# #### 7. Data Description
# This datset provides some major characteristics of car from differnt car manufacturing brands like toyota, Distinct Values
# alfa-romero, audi, bmw, chevrolet, dodge, honda, isuzu, jaguar, mazda, mercedes-benz, mercury, mitsubishi, nissan, peugot, plymouth, porsche, renault, saab, subaru, volkswagen and volvo.More deatails can be founded in the following chart:
#
#
# | Column Name                    | Description                                                                                |
# | -------------------------------|:------------------------------------------------------------------------------------------:|
# | Symboling                      | Corresponds to the degree the auto is more risky compared to its price.                    |
# | Normalized-Losses              | Is the relative average loss payment per insured vehicle                                   |
# | Make                           | Refers to differnt brands                                                                  |
# | Fuel Type                      | Tpye of fuel which provides power for engine of a car (gas, deisel)                        |
# | Aspiration                     | Refers to breathing of an auto (std, turbo)|
# | Number of Doors                | Corresponds to the number of doors of an auto (four, two)                                  |
# | Body Style                     | Refers to the shape and model of an auto(5 unique values)                                  |
# | Wheels Drive                   | Corresponds to the number of wheels that are driven(Rear wheel drive, front and four wheel drive|
# | Engine Location                | Refers to the location of the engine in an auto (front, rear)|
# | Wheel Base                     | Is distance between the centers of front and rear wheels|
# | Dimentions(length, height,width| Three dimentions(Length, Hieght, Width)                                              |
# | Curb Weight                    | Reffers to the weight of the auto with all standard equipments|
# | Engine Type                    | Refers to differnt features of the engine(7 unique values)
# | Number of Cylinders            | It is a power unit of an engine(7 uniue values)
# | Fuel System                    | Refers to a set of components deliver fue from tank to engine(8 unique values)
# | Bore                           | Refers to diameter of cylinder
# | Stroke                         | Refers to a piston inside the cylinder rides up and down
# | Compression Ratio              | Is volume of the cylinder
# | Horsepower                     | Refers to the power of engine of the auto
# | Peak rmp                       | How fast any engine of autos operating in a given time
# | City MPG                       | Driving with occasional stoping and breaking
# | Highway MPG                    | Driving more continuously
# | Price                          | Refers to the value of the auto

# %% [markdown]
# -  **Info Function:** This function is a part of description and gives interesting insights into the dataset.

# %%
Am_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 26 columns):
# symboling            5 non-null int64
# normalized-losses    5 non-null object
# make                 5 non-null object
# fuel-type            5 non-null object
# aspiration           5 non-null object
# num-of-doors         5 non-null object
# body-style           5 non-null object
# drive-wheels         5 non-null object
# engine-location      5 non-null object
# wheel-base           5 non-null float64
# length               5 non-null float64
# width                5 non-null float64
# height               5 non-null float64
# curb-weight          5 non-null int64
# engine-type          5 non-null object
# num-of-cylinders     5 non-null object
# engine-size          5 non-null int64
# fuel-system          5 non-null object
# bore                 5 non-null object
# stroke               5 non-null object
# compression-ratio    5 non-null float64
# ...

# %% [markdown]
# - By executing info function, the following information on automobile datase have been extracted:
#     - There are 205 rows(samples) and 26 columns(variables).
#     - There are 10 columns with numeric datatype (5 columns with float value and 5 columns with integer value and 16 columns with object datatype.
#     - There is no any missing value in this dataset as per infor function.

# %% [markdown]
# - **describe function:** By executing describe function, all descriptive statistics will be measured which consists of brief descriptive coefficients that summarize a given data set, which can be either a representation of the entire or a sample of a population.

# %%
Am_df.describe()
# Out:
#        symboling  wheel-base      length      width     height  curb-weight  \
# count    5.00000    5.000000    5.000000   5.000000   5.000000     5.000000
# mean     2.20000   94.180000  172.400000  65.260000  51.720000  2616.000000
# std      0.83666    5.504725    3.957272   1.110405   2.776148   208.087722
# min      1.00000   88.600000  168.800000  64.100000  48.800000  2337.000000
# 25%      2.00000   88.600000  168.800000  64.100000  48.800000  2548.000000
# 50%      2.00000   94.500000  171.200000  65.500000  52.400000  2548.000000
# 75%      3.00000   99.400000  176.600000  66.200000  54.300000  2823.000000
# max      3.00000   99.800000  176.600000  66.400000  54.300000  2824.000000
#
#        engine-size  compression-ratio   city-mpg  highway-mpg
# count     5.000000           5.000000   5.000000     5.000000
# mean    131.400000           9.000000  20.600000    26.400000
# std      15.420765           0.707107   2.302173     2.880972
# ...

# %% [markdown]
# - **Observations:** Considering the descreptive statistics extracted by executing describe function, the following insights have given into the dataset:
#     - a. symboling, whell-base, length, width, height, compression-ratio, city-mpg and highway-mpg columns have almost **normal distribution** because their mean values are very close to their median.
#     - b. in curb-weight column, mean value(2555.6) is greater than its median value (2414.0) so the distribution is positively skewed(positive skewness). Therefore, most of the samples(autos) weighted less than 2555.5 unit.
#     - c. curb weight of cars is vary from 1488 unit to 4066 unit.
#     - d. symboling column illustrates that 75% of autos are likely to be more risky.
#     - e. Interms of engine size atribute, mean value(127) is greater than median value (120). Therefore, we can say that there is a positive skewness and engine size of the most autos are less than 127 unit.

# %% [markdown]
# <a id=section8></a>
# #### 8. Pandas Profiling before Data Processing
# - Before doing data processing, we need to know how the data exactly are. Performing profiling help us to go in each column one by one and see what is going on there. Pandas profiling provides such a woderful platform that shows each and every aspect of the dataset.
# - By executing the codes of pandas profiling, an output file will be existed. This file can be stored into ways:
#     - a. Directory of the notebook.
#     - b. Current jupyter notebook.

# %%
#profile = Am_df.profile_report(title = "Am_df before data processing")
#profile.to_file(output_file = "Am_df_profiling_before_processing.html")

# %% [markdown]
# **Observation from pandas profiling before data processing:**
# -  Dataset info
#
#     - Number of variables   : 26
#     - Number of observations: 205
#     - Missing cells         : 0 (0.0%)
#     - Duplicate rows        : 0 (0.0%)
#     - Total size in memory  : 41.7 KiB
#
# - 1. Variables types
#     - Numeric               : 9
#     - Categorical           : 16
#     - Rejected              : 1
#
# - 2. Warnings
#     - highway-mpg is highly correlated with city-mpg (ρ = 0.9713370423)  	Rejected
#     - horsepower has a high cardinality: 60 distinct values              	Warning
#     - normalized-losses has a high cardinality: 52 distinct values      	Warning
#     - price has a high cardinality: 187 distinct values                 	Warning
#     - symboling has 67 (32.7%)                                              zeros
#     - Existing zeros in symboling column is totally aceptable because symboling refers to degree of being more risky or being more safe between -3 and +3 which consisting zero as well.
#     - Warnings in horsepower, normalized losses and price columns should be taken into consideration seriously because they have remarkable disticnt values wheas naturally these columns have numeric values with no distinction.
#     - highwat mpg and city mpg is highly correlated so there is no need to analyze both colunms.
#
# - 3. Variables(columns)
#     - **Aspiration** has two distinct values(std and turbo with 82% share and 18% share respectively)
#     - **Body style** consisting of five distinct values that sedan style with 46.8% is in the highest position and convertible style with 2.9% is in the lowest position among all body styles of autos.
#     - **Compression ration**
#         - compression ratio distribution is almost normal because the mean value is 10 and the median value is 9 which are close to each other.
#         - It has a skewness of 2.6 and kurtosis of 5.2.
#         - Since skewness is greater than +1, it is highly positively skewed.
#         - Since kurtosis is +5.2, it is leptokurtic. In leptokurtic, the peak is sharper and the tails are heavier and there high possibility of outliers.
#         - 95% of the samples(autos) lies less than 21.8 unit.
#     - **Curb weight**
#         - It has a mean value of 2556 and median value of 2414.
#         - Since mean value is greater than median value, skewness is positive and so most of the autos weighted less than mean value(2556).
#         - Curb weight distribution has a kurtosis of -0.04 means the the kutosis is negative but very close to zero so it is almost mesokurtic and therefore, there is no any outlier.
#         - 75% of samples(autos) weighted less than 2935 unit.
#         - Standard deviation is 520.68 indicates that curb weight of eache auto is varied 520.68 from the mean on average basis.
#     - **Drive wheels**
#         - Autos are divided on the basis of driving wheels into three categories namely front wheel drive (fwd), two wheel drive(rwd) and four wheel drive(4wd). fwd with 58.5% is the hihghest in the samples.
#     - **Engine location**
#         - There are two unique categories; front and rear.
#         - 98.5% of autos have their engines in front of their bodies.
#         - only 1.5% of autos have the engine in rear of their bodies.
#     - **Engine size**
#         - Engine size disribution has a positive kurtosis of 5.3 which is called leptokurtic. In leptokurtic distribution, there are outliers.
#         - It has a skewness of about 2 (greater than +1) so the distribution has a high positive skewness.
#         - 95% of samples(autos) have engine size of less than 201 unit.
#     - **Engine type**
#         - It has 7 unique categories. ohc type with 72.2% is the highest and the dohcv type with 0.5% is the lowest.
#     - **height**
#         - It has a skewness of 0.06(less than +1) so the distribution is almost normal.
#         - It has a kurtosis of -0.4 so the distribution is platykurtic(with flatter peak and lighter tails) with no outliers.
#     - **Length**: looks normal because there are no any outliers and no missing values.
#     - **Number of cylinders**
#         - It has 7 unique categories.
#         - Four cylinder autos are with 77.6% in the highest position and twelve cylinder autos are with 0.5% in the lowest.
#     - **Symboling**
#         - Based on mean value(0.8) and median value(1), the distribution is less negatively skewed or almost normal.
#         - Kurtosis is -0.7 indicating platykurtic. so, there is no any extreme value(outlier).
#         - 32.7% of the distribution is **zero**. It is quiet acceptable because zeros are par of the scale of assessing the riskness of autos.
#     - **Wheel base**
#         - 95% autos have a wheel base of less than 110 unit.
#         - It has a skewness and kurtosis of about 1.
#         - Since skewness is 1 or mean value is 98 and median value is 97 and very close to each other, there is a normal ditribution.
#         - Kurtosis is 1 so the tails of distribution are abit heavier and the peak is alittle sharper.
#      - **Horsepower**
#         - It has 60 distinct values which is not reasonable because horsepower is a numeric value in nature. But profiling shows an question mark(?) within the column that is why this variable has been markek as categorical value.
#      - **Normalized losses**
#         - It has 52 distinct values.
#         - Normalized losses is a numerical values in nature but it has been cosidered as categorical value so it can be targeted as an abnormal condition.
#         - Again question mark(?) is within the column.
#      - **Number of doors, Peak rpm, price, stroke and bore have the same situation like horsepower and normalized losses**

# %% [markdown]
# <a id=section9></a>
# #### 9. Data Processing
# - In data profiling, all variables are understood one by one. Some variable were quite qualified for **Exploratory Data Analysis** whereas some of them still need further processing to be qualified for EDA and thes variables are identified for processing and cleaning.
# - 1. Normalize losses: Replacing '?' with mean value.
# - 2. Horsepower: Replacing '?' with mean value.
# - 3. Number of doors: Replacing with Mode value.
# - 4. Peak RPM : Converting the non-numeric value to null and convert to dtype.
# - 5. Price : Finding the mean and replacing with non-numeric values.
# - 6. Stroke: Converting non-numeric to numeric values.
# - 7. bore: Converting non-numeric to numeric values.
# - **In order to fix the above irregularities, the following operations will be performed:**

# %% [markdown]
#  **9.1. Dealing with normalized losses**
# - **steps:**
#     - 1. Finding out number of records having "?": 41
#     - 2. Finding out number of records having integer values: 164
#     - 3. Mean value calculation of integer values: 164.0
#     - 4. Replacing "?" with mean value.
#     - 5. Printing five top values.

# %%
Am_df["normalized-losses"].loc[Am_df["normalized-losses"]=="?"].count()
# Out:
# 3

# %%
Normalized_df = Am_df["normalized-losses"].loc[Am_df["normalized-losses"]!="?"].count()
Normalized_df
# Out:
# 2

# %%
nlmean = Normalized_df.astype(str).astype(int).mean()

# %%
Am_df["normalized-losses"] = Am_df["normalized-losses"].replace("?", nlmean).astype(int)

# %%
Am_df["normalized-losses"].head()
# Out:
# 0      2
# 1      2
# 2      2
# 3    164
# 4    164
# Name: normalized-losses, dtype: int32

# %% [markdown]
#  **9.2. Dealing with Horsepower**
# - **steps:**
#     - 1. Finding out number of records having "?": 2
#     - 2. Finding out number of records having integer values: 203
#     - 3. Mean value calculation of integer values: 203.0
#     - 4. Replacing "?" with mean value.
#     - 5. Printing five top values.

# %%
Am_df["horsepower"].loc[Am_df["horsepower"]=="?"].count()
# Out:
# 0

# %%
HP = Am_df["horsepower"].loc[Am_df["horsepower"] != "?"].count()
HP
# Out:
# 5

# %%
hpmean = HP.astype(str).astype(int).mean()
hpmean
# Out:
# 5.0

# %%
Am_df["horsepower"] = Am_df["horsepower"].replace("?", hpmean).astype(int)

# %%
Am_df["horsepower"].head()
# Out:
# 0    111
# 1    111
# 2    154
# 3    102
# 4    115
# Name: horsepower, dtype: int32

# %% [markdown]
#  **9.3. Dealing with Number of doors**
# - **steps:**
#     - 1. Finding out number of records having "?": 2
#     - 2. Finding out number of records having integer values: 203
#     - 3. **Mode** value of the column: four*
#     - 4. Replacing "?" with mode.
#     - 5. Printing five top values.
#     - ***Note:** Since the four appears most frequently, so we cat take it as mode.

# %%
Am_df["num-of-doors"].loc[Am_df["num-of-doors"]=="?"].count()
# Out:
# 0

# %%
Am_df["num-of-doors"].value_counts()
# Out:
# two     3
# four    2
# Name: num-of-doors, dtype: int64

# %%
Am_df["num-of-doors"] = Am_df["num-of-doors"].replace("?", "four")

# %%
Am_df["num-of-doors"].value_counts()
# Out:
# two     3
# four    2
# Name: num-of-doors, dtype: int64

# %%
Am_df["num-of-doors"].head()
# Out:
# 0     two
# 1     two
# 2     two
# 3    four
# 4    four
# Name: num-of-doors, dtype: object

# %% [markdown]
# **9.4. Dealing with peak RPM:**
# - **Steps**
#     - 1. Finding out the number of invalid value:   2
#     - 2. Converting the non-numeric value to null and convert to dtype.
#     - 3. Print first five values.

# %%
Am_df["peak-rpm"].loc[Am_df["peak-rpm"] == "?"].count()
# Out:
# 0

# %%
Am_df["peak-rpm"] = pd.to_numeric(Am_df["peak-rpm"], errors = "coerc")

# %%
Am_df = Am_df[Am_df['peak-rpm'].notna()]

# %%
Am_df["peak-rpm"].head()
# Out:
# 0    5000
# 1    5000
# 2    5000
# 3    5500
# 4    5500
# Name: peak-rpm, dtype: int64

# %% [markdown]
# **9.4. Dealing with Price:**
# - **Steps**
#     - 1. Finding out the number of values which are not numeric.
#     - 2. Listing out the number of values which are numeric.
#     - 3. Finding the mean and replacing with non-numeric values.

# %%
Am_df["price"].loc[Am_df["price"]== "?"].count()
# Out:
# 0

# %%
Am_df["price"].loc[Am_df["price"]!= "?"].count()
# Out:
# 5

# %%
p = Am_df["price"].loc[Am_df["price"] != "?"]

# %%
Pmean = p.astype(str).astype(int).mean()
Pmean
# Out:
# 15579.0

# %%
Am_df["price"] = Am_df["price"].replace("?", Pmean).astype(int)

# %%
Am_df["price"].head()
# Out:
# 0    13495
# 1    16500
# 2    16500
# 3    13950
# 4    17450
# Name: price, dtype: int32

# %% [markdown]
# **9.5. Dealing with Bore:**
# - **Steps**
#     - 1. Finding out the number of values which are not numeric.
#     - 2. Listing out the number of values which are numeric.
#     - 3. Converting non-numeric to numeric values.
#     - 4. Removing nan values values.

# %%
Am_df["bore"].loc[Am_df["bore"]=="?"].count()
# Out:
# 0

# %%
Am_df["bore"].loc[Am_df["bore"] != "?"].count()
# Out:
# 5

# %%
Price_df = Am_df["bore"].loc[Am_df["bore"] != "?"]

# %%
Am_df["bore"] = pd.to_numeric(Am_df["bore"], errors = "coerce")

# %%
Am_df = Am_df[Am_df['bore'].notna()]

# %%
Am_df["bore"].head()
# Out:
# 0    3.47
# 1    3.47
# 2    2.68
# 3    3.19
# 4    3.19
# Name: bore, dtype: float64

# %% [markdown]
# **9.6. Dealing with stroke:**
# - **Converting non-numeric to numeric values.**

# %%
Am_df["stroke"].dtype
# Out:
# dtype('O')

# %%
Am_df["stroke"] = pd.to_numeric(Am_df["stroke"], errors = "coerc")

# %%
Am_df["stroke"].dtype
# Out:
# dtype('float64')

# %%
Am_df["stroke"].head()
# Out:
# 0    2.68
# 1    2.68
# 2    3.47
# 3    3.40
# 4    3.40
# Name: stroke, dtype: float64

# %% [markdown]
# <a id=section10></a>
# #### 10. Pandas Profiling after Data processing

# %%
#profile = Am_df.profile_report(title = "Am_df after data processing")
#profile.to_file(output_file = "Am_df_profiling_after_processing.html")

# %% [markdown]
# **10.1. Observation from pandas profiling before data processing:**
# -  Dataset info
#
#     - Number of variables   : 27
#     - Number of observations: 199
#     - Missing cells         : 0 (0.0%)
#     - Duplicate rows        : 0 (0.0%)
#     - Total size in memory  : 42.1 KiB
#
# - 1. Variables types
#     - Numeric               : 16
#     - Categorical           : 10
#     - Rejected              : 1
#
# - 2. Warnings
#     - highway-mpg is highly correlated with city-mpg (ρ = 0.9713370423)  	Rejected
#     - symboling has 67 (32.7%)                                              zeros
#     - Existing zeros in symboling column like before processing is totally aceptable because symboling refers to degree of being more risky or being more safe between -3 and +3 which consisting zero as well.
#     - Warnings in horsepower, normalized losses and price columns have been removed after data processing.
#
# - 3. Variables(columns) which were surrounded by irregularities, have been solved by data processing manipulation. Now, considering the pandas profiling after data processing, the following obsevations related to variables having irregularities obtained:
#
#      - **Horsepower**
#         - It has a skewness of 1.3 and kurtosis of 2.5.
#         - Since skewnes is greater than +1, there is a positive skewness and horsepower of autos are more spread out.
#         - Since kurtosis is positive, there is a leptokurtic. Means the peak of horsepower distribution is sharper and its tails are heavier.
#         - 95% of outos have less than 188 horsepower.
#      - **Normalized losses**
#         - It has a mean value of 129 and a median vulue of 128.
#         - Since mean value and median value are close to each other, the distribution is normal.
#         - 75% of autos having normalized losses of less than 164 unit.
#      - **Number of doors**
#         - This column had some invalid values.But, now there is no any invalide values.
#         - It has two unique categories namely two and four doors with share of 42.2% and 57.8% respectively.
#      - **Peak rpm**
#         - It has a kurtosis of 0.2 and a skewness of 0.06.
#         - 50% of autos have a peak rpm of less than 5200.
#      - **price**
#         - It has a mean value of 13247 and median value of 10342 indicating that mean is greater than median so there is a high positive skewness.
#         - It has a kewness of 1.8 and kurtosis of 3.2.
#         - This high and positive kurtosis indicates that the price distribution is very heavy in its tails so there are extreme values(outliers)
#      - **stroke**
#         - Mean value and median value is very close tho each other so the stroke distributio is normal.
#         - 25% of autos have stroke with less than 3.11 and 95% of autos have less than 3.64.
#      - **bore**
#         - It has a skewness value of 0.03 and kurtosis value of -0.8.
#         - Since the kurtosis is negative so there is a platykurtic means the tails are not heavy and there are no outliers.

# %% [markdown]
# **10.2. Figuring out the descriptive statistics of cleaned data**

# %%
Am_df.describe()
# Out:
#        symboling  normalized-losses  wheel-base      length      width  \
# count    5.00000           5.000000    5.000000    5.000000   5.000000
# mean     2.20000          66.800000   94.180000  172.400000  65.260000
# std      0.83666          88.731054    5.504725    3.957272   1.110405
# min      1.00000           2.000000   88.600000  168.800000  64.100000
# 25%      2.00000           2.000000   88.600000  168.800000  64.100000
# 50%      2.00000           2.000000   94.500000  171.200000  65.500000
# 75%      3.00000         164.000000   99.400000  176.600000  66.200000
# max      3.00000         164.000000   99.800000  176.600000  66.400000
#
#           height  curb-weight  engine-size      bore    stroke  \
# count   5.000000     5.000000     5.000000  5.000000  5.000000
# mean   51.720000  2616.000000   131.400000  3.200000  3.126000
# std     2.776148   208.087722    15.420765  0.322645  0.408142
# min    48.800000  2337.000000   109.000000  2.680000  2.680000
# ...

# %% [markdown]
# **10.3. Saving the cleaned data to a local file**

# %%
Am_df.to_csv(r'C:\Users\ZeytoonCo\Desktop\Automobile_data_processed.csv', index=False)

# %%
Ap_df = pd.read_csv(r'C:\Users\ZeytoonCo\Desktop\Python files\EDA\My_Project\Automobile_data_processed.csv')
Ap_df.round(decimals = 2)
Ap_df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                164  alfa-romero       gas        std
# 1          3                164  alfa-romero       gas        std
# 2          1                164  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
# 2          two    hatchback          rwd           front        94.5   171.2
# 3         four        sedan          fwd           front        99.8   176.6
# 4         four        sedan          4wd           front        99.4   176.6
#
#    width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
#import pandas_profiling
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
title_color = "navy"
plot_color = "crimson"
plot_alt_color = "coral"
plot_color_secondary = "deepskyblue"
y_title_margin = 1.0

# %% [markdown]
# <a id=section11></a>
# #### 11. Univariate Analysis
# Univariate analyzes are used extensively in quality of life research. Univariate analysis is defined as analysis carried out on only one (“uni”) variable (“variate”) to summarize or describe the variable (Babbie, 2007; Trochim, 2006). However, another use of the term “univariate analysis” exists and refers to statistical analyses that involve only one dependent variable and which are used to test hypotheses and draw inferences about populations based on samples, also referred to as univariate statistics (Tabachnick & Fidell, 2007).
#
#
# - **A. Categorical variable analysis:**

# %% [markdown]
# - **Question 1:**
# How much autos are more risky and more safe in respect to their prices?

# %%
space = np.ones(6)/28
Ap_df["symboling"].value_counts().plot(kind = "pie", figsize = (13,6), fontsize = 13, shadow = True, autopct =
                                       "%2.1f%%", explode = (0.03571429, 0.03571429, 0.03571429, 0.03571429, 0.03571429,
       0.571429))
plt.title("Pie chart illustrating autos riskness ", fontsize=13, fontweight="bold")
plt.ylabel("Symboling", fontsize=13, fontweight="bold")
# Out:
# Text(0, 0.5, 'Symboling')

# %% [markdown]
# **Observations:**
# - 11.6% of autos are more risky and 1.5% of autos are more safe in respect to their prices.
# - 33.2% of the autos are in the middle interms of being riskness related to their prices.

# %% [markdown]
# - **Question 2:** How much are the normalized losses compared to each other?

# %%
Ap_df["normalized-losses"].plot(kind="hist",figsize=(10,5), bins = 30, color = "teal", fontsize = 13,
                               edgecolor="red") #plot continuous data histogramm is used.
plt.xlabel("Normalized Losses", fontsize=13)
plt.ylabel("Number of Autos", fontsize=13)
plt.title("Histogram illustrating Normalized Losses of Autos", fontsize=13)
plt.style.use("seaborn-whitegrid")

# %% [markdown]
# **Observations:**
# - More than 50 autos have about 160 normalized losses in use as compared to
# other autos.
# - There are about 2 autos having 230 normalized losses which are considered as outiers.

# %%
plt.figure(figsize=(10,5))
sns.distplot(Ap_df["normalized-losses"], hist=True, kde=True, 
             bins=30, color = "darkblue", 
             hist_kws={"edgecolor":"green"},
             kde_kws={"linewidth": 2})
plt.xlabel("Normalized Losses", fontsize=13)
plt.ylabel("Density", fontsize=13)
plt.title("Histogram illustrating Normalized Losses of Autos", fontsize=12, fontweight="bold")
plt.style.use("seaborn-whitegrid")

# %% [markdown]
# **Observations:**
# - As the Kernel Density Estimation(kde) illustrates, there is a bimodal distribution with right long tail.
# - Data are compacted into two areas; firstly around 100 normalized losses and secondly, around 160 normalized losses means the normalized losses are more in these two points compared to others.
# - Long tail in the right side showing positive skewness.

# %% [markdown]
# **Questions No. 3:** Which brand has the best selling rate?

# %%
#plt.figure(figsize=(13,7))
Ap_df["make"].value_counts().plot(kind="pie",wedgeprops=dict(width=0.15),shadow=True, explode=np.ones(21)/15,autopct="%1.2f%%",  
                            startangle=160, figsize=(15,10),
                                                                   cmap="inferno")
plt.legend(fontsize=11, loc="center", ncol=2, title="Brand")
plt.title("Donut Chart showing  percentage of Autos sold by Brands", fontsize=13,fontweight = "bold")
plt.ylabel("Make", fontsize=12, fontweight="bold")
# Out:
# Text(0, 0.5, 'Make')

# %% [markdown]
# **Observations:**
# - Toyota brand with 16.1% has the hieghest selling rate and Mercury with 0.5% has the lowest selling rate.
# - Five top brand in terms of selling rate are Toyota, Nissan, Mitsubishi, Honda and Mazda.

# %% [markdown]
# **Question NO. 4:** Which fuel type autos are prefered by customers more?

# %%
Ap_df["fuel-type"].value_counts().plot(kind="barh", figsize=(10,5), fontsize=13, color="m")
plt.xlabel("Number of Autos",fontsize=13,fontweight="bold")
plt.ylabel("Fuel Type", fontsize=13, fontweight="bold")
plt.title("Bar Chart illustrating fuel type of autos", fontsize=13, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Bar Chart illustrating fuel type of autos')

# %% [markdown]
# **Observations:**
# - About 180 autos which are powered by gas are prefered by customers.
# - About 20 autos are powered by diesel.

# %% [markdown]
# **Question 5:**Which type of breathing is more prefered by customers?

# %%
Ap_df["aspiration"].value_counts().plot(kind="pie", explode = np.ones(2)/14, shadow=True, autopct="%2.1f%%",fontsize=13,
                                       figsize=(10,5),colors=[plot_color, plot_color_secondary], startangle=50)
plt.ylabel("Aspiration",fontsize=13, fontweight="bold")
plt.legend(fontsize=12, loc="upper right")
plt.title("Pie chart showing standard and turbo breathing", fontsize=13, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Pie chart showing standard and turbo breathing')

# %% [markdown]
# **Observations:**
# - 81.4% of autos breathing standard and only 18.6% are having turbo aspiration.

# %% [markdown]
# **Question 6:** Are number of doors important for customers?

# %%
Ap_df["num-of-doors"].value_counts().plot(kind="bar", fontsize=13, color="y", figsize=(10,5))
plt.xlabel("Number of Doors", fontsize=13, fontweight="bold")
plt.ylabel("Number of Autos", fontsize=13, fontweight="bold")
plt.title("Bar chart illustrating Autos having Four and Two doors", fontsize=13, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Bar chart illustrating Autos having Four and Two doors')

# %% [markdown]
# **Observations:**
# - About 120 autos sold are four doors whereas approximately 85 autos sold are two doors. So four doors are morer prefered by customers compared to two doors.

# %% [markdown]
# **Question 7:** Which body style is most preferred by customers?

# %%
Ap_df["body-style"].value_counts().plot(kind="bar", color="orangered", fontsize=13, figsize=(10,5))
plt.xlabel("Body Style", fontsize=13,fontweight="bold")
plt.ylabel("Number of Autos", fontsize=13, fontweight="bold") 
plt.title("Barchart showing body type of autos", fontsize=13, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Barchart showing body type of autos')

# %% [markdown]
# **Observations:**
# -  According to body style, Sedan is on the top following by Hatchback.

# %% [markdown]
# **Question 9:** Which drive wheels categories of autos are in the top?

# %%
Ap_df["drive-wheels"].value_counts().plot(kind="pie", explode = np.ones(3)/8, shadow=True, autopct="%2.1f%%",fontsize=13,
                                       figsize=(10,5))
plt.ylabel("Drive Wheels",fontsize=13, fontweight="bold")
plt.legend()
plt.title("Pie chart showing autos wheels by drive", fontsize=13, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Pie chart showing autos wheels by drive')

# %% [markdown]
# **Observations:**
# - Front Wheel drive is the most desirable for customers which having 59.3%.
# - Rear Wheel Drive and Four Wheel drive with having 36.2% and 4.5% respectively are in second and fourth position.

# %% [markdown]
# **Question 10:** Are number of cylinders important?

# %%
Ap_df["num-of-cylinders"].value_counts().plot(kind="bar", color="deeppink",figsize=(10,5), fontsize=13)
plt.xlabel("Number of cylinders", fontsize=13,fontweight = "bold")
plt.ylabel("Number of Autos", fontsize=13, fontweight = "bold")
plt.title("Bar Chart showing Number of cylinders", fontsize=13,fontweight = "bold")
plt.style.use("seaborn-white")

# %% [markdown]
# **Observations**
# - Four cylinders are the most desirable and three cylinders are lest desirabl.

# %% [markdown]
# **Question 11:** Which type of engine is dersirable for customers on the basis of engine locations?

# %%
Ap_df["engine-type"].value_counts().plot(kind="bar",figsize=(10,5), color = "navy", fontsize = 13)
plt.xlabel("Engine-type", fontsize=13, fontweight="bold")
plt.ylabel("Number of Autos", fontsize=13, fontweight="bold")
plt.title("Histogram illustrating Type of Engine", fontsize=13, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Histogram illustrating Type of Engine')

# %% [markdown]
# **Observations:**
# - On the basis of engine type, OHC is top dersirable and DOHCV is very desirable.

# %% [markdown]
# **Question 12:** What type of autos are most preferable on the basis of engine location?

# %%
Ap_df["engine-location"].value_counts().plot(kind="bar", color="c",figsize=(10,5), fontsize=13)
plt.xlabel("Engine Location", fontsize=12,fontweight = "bold")
plt.ylabel("Number of Autos", fontsize=12, fontweight = "bold")
plt.title("Bar Chart showing Engine Location Disribution", fontsize=12,fontweight = "bold")
# Out:
# Text(0.5, 1.0, 'Bar Chart showing Engine Location Disribution')

# %% [markdown]
# **Observation:**
# - Nearly all customers prefered to buy front engine location.

# %% [markdown]
# **Question 13:** How is the distribution of compression ratio?

# %%
Ap_df["compression-ratio"].plot(kind="kde",figsize=(10,5), color = "navy", fontsize = 13)
plt.xlabel("Compression Ratio", fontsize=13, fontweight="bold")
plt.ylabel("Density", fontsize=13, fontweight="bold")
plt.title("Histogram illustrating Compression Ratio", fontsize=13, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Histogram illustrating Compression Ratio')

# %% [markdown]
# **Observation:**
# - As KDE illustrates most of autos having compression ratio of about 10.
# - A few number of autos have compression ratio of about 30 which are considered as outliers.

# %% [markdown]
# **Question 14:** What type of autos are most desirable on the basis of fuel type?

# %%
Ap_df["fuel-type"].value_counts().plot(kind="pie", startangle=50, autopct="%1.1f%%", explode=np.ones(2)/16, shadow=True,
                                      fontsize=12)
plt.ylabel("Fuel Type",fontsize=13, fontweight="bold")
plt.legend(fontsize=12, loc="upper right")
plt.title("Pie chart showing Fuel Type Distribution", fontsize=13, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Pie chart showing Fuel Type Distribution')

# %% [markdown]
# **Observation:**
# - 90% of autos using gas and only 10% using deisel prefered by customers.

# %% [markdown]
# **B. Continuous Variables Analysis**
#
#
# - **Question 15:** What are the patterns in continuous characteristics of autos?

# %%
fig,ax = plt.subplots(figsize=(10,5), ncols=1, nrows=1)
fig.patch.set_alpha(.7)

Ap_df[['wheel-base','length','width','height']].hist(color='hotpink',
ax=ax, edgecolor=plot_color_secondary, linewidth=1)
plt.show()

# %% [markdown]
# **Observations:**
# - Height, Length and Wheel base follow almost normal distribution.
# - Width does not follow normal distribution rather it shows a psitive skewness; most of autos having width between 63 and 68.

# %%
Ap_df["price"].plot(kind="kde",figsize=(8,4), color = "red", fontsize = 11)
plt.xlabel("Price", fontsize=13, fontweight="bold")
plt.ylabel("Density", fontsize=13, fontweight="bold")
plt.title("KDE Plot illustrating Price Distribution", fontsize=13, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'KDE Plot illustrating Price Distribution')

# %% [markdown]
# **Observation:** Density plot of price illustrates that price of autos compacted more in somewhere about 10000, and also shows afew autos having pricing of more than 50000.

# %%
fig,ax = plt.subplots(figsize=(10,5), ncols=1, nrows=1)
fig.patch.set_alpha(.7)

Ap_df[['engine-size','peak-rpm','curb-weight','horsepower']].hist(color='b',
ax=ax, edgecolor=plot_color_secondary, linewidth=1)
plt.show()

# %% [markdown]
# **Observations:**
# - Autos having between 2000 and 2500 curb weith have the highest frequency.
# - Autos havive 100 engine size have the highest count compared to other outos.
# - Interms of horsepower, about 55 autos have the lowest horsepower and a few autos have the highest horsepower between 250 and 280.
# - Autos with peak rpm of 5500 have the highest frequency.

# %%
Ap_df["stroke"].plot(kind="hist",figsize=(10,5), color = "navy",edgecolor="red" ,fontsize = 11, alpha=0.5)
plt.xlabel("Stroke", fontsize=12, fontweight="bold")
plt.title("Histogram illustrating Machine Stroke Distribution", fontsize=12, fontweight="bold")
plt.grid(color="w", linestyle="solid")
plt.ylabel("Frequency", fontsize=12, fontweight="bold")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# **Observations:**
# - What inference from machine stroke distribution is that about 70 autos have 3.4 unit.

# %% [markdown]
# <a id=section12></a>
# #### 12. Bivariate Analysis
# Bivariate analysis is the simultaneous analysis of two variables (attributes). It explores the concept of relationship between two variables, whether there exists an association and the strength of this association, or whether there are differences between two variables and the significance of these differences.

# %% [markdown]
# **Question 15:** What is the relationship between price and risk rating?

# %%
plt.figure(figsize=(10,5))
sns.regplot(data=Ap_df, x="symboling",y="price",  color="red")
plt.xlabel("Risk Rating", fontsize=12, fontweight="bold")
plt.ylabel("Price", fontsize=12, fontweight="bold")
plt.title(" Regplot illustrating Price by Symboling", fontsize=12, fontweight="bold")
# Out:
# Text(0.5, 1.0, ' Regplot illustrating Price by Symboling')

# %% [markdown]
# **Observation:**
# - As regression live illustrates, there is a low positive correlation between price and risk rating. As price goes up, the degree of autos' safty also goes up very fast.

# %% [markdown]
# **Question 16:** What are the five top expensive brands?

# %%
Ap_df.groupby(["make"])["price"].mean().sort_values().plot(kind="bar",figsize=(10,5), fontsize=12, color="darkcyan")
plt.xlabel("Make", fontsize=12, fontweight="bold")
plt.ylabel("Price", fontsize=12, fontweight="bold")
plt.title("Bar Chart illustrating price of Each Brand", fontsize=12, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Bar Chart illustrating price of Each Brand')

# %% [markdown]
# **Observations:**
# - Jaguar, Mercedes Benz, Porche, BMW and Volvo are top five most expensive brands.
# - Jaguar is the most expensive brand and the Chevrolet is the cheapest one.

# %% [markdown]
# **Question 17:** Which body style is most expensive?

# %%
fig, ax = plt.subplots(figsize=(10,5), ncols=1, nrows=1)

#fig.patch.set_alpha(0)
#ax.patch.set_alpha(0)

sns.violinplot(data=Ap_df, x="body-style", y="price", bw=0.2, cut=5, linewidth=1, ax=ax)
plt.xlabel("Body Style", fontsize=12, fontweight="bold")
plt.ylabel("Price", fontsize=12, fontweight="bold")
plt.title("Violin Plot illustrating Price by Body Style", fontsize=12, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Violin Plot illustrating Price by Body Style')

# %% [markdown]
# **Observations:**
# - Hardtop and Convertible are the most expensive body style compared to other body styles.
# - In the meanwhile, the distribution of price is more vary in the Hardtop, sadan and convertible body styles.
# - Some level of skewness is there in each body style but Hatchback has less skewed data compared to other body styles.

# %% [markdown]
# **Questions 19:** Which body style has more city mileage?

# %%
Ap_df.groupby(["body-style"])["city-mpg"].mean().sort_values(ascending=False).plot(kind="bar",
                                          figsize=(10, 5),color=plot_color,fontsize=12)
plt.xlabel("Body Style", fontsize=12, fontweight="bold")
plt.ylabel("City Mileage", fontsize=12, fontweight="bold")
plt.title("Bar Chart illustrating City Mileage by Body Style", fontsize=12, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Bar Chart illustrating City Mileage by Body Style')

# %% [markdown]
# **Obsrvations:**
# - Though city mileage is not so distinctguished but overall Hatchback has more and Convertible body style has less city mileage.

# %% [markdown]
# **Question 20:** Do number of cylinder affect the price of the auto?

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=Ap_df, x='num-of-cylinders', y="price", orient="vertical", color="orchid")
plt.xlabel("Number of Cylinders", fontsize=12, fontweight="bold")
plt.ylabel("Price", fontsize=12, fontweight="bold")
plt.title(" Boxplot illustrating Price by Number of Cylinders", fontsize=12, fontweight="bold")
# Out:
# Text(0.5, 1.0, ' Boxplot illustrating Price by Number of Cylinders')

# %% [markdown]
# **Observations:**
# - Twelve cylinders auto is the most expencive outo and its amount is extremely less.
# - Second most expensive outo is eight cylinders, but outliers are there.
# - Three cylinders autos have the lowest price among all autos.

# %% [markdown]
# **Question 21:** Which type of breathing autos have more horsepower?

# %%
plt.style.use("seaborn-white")

# %%
#sns.set(rc={"figure.figsize":(10,5)})
plt.figure(figsize=(10,5))

sns.swarmplot(data=Ap_df, x="aspiration", y="horsepower")
sns.violinplot(data=Ap_df, x="aspiration", y="horsepower", color="w", edgecolor="red")
plt.xlabel("Apiration", fontsize=12, fontweight="bold")
plt.ylabel("Horsepower", fontsize=12, fontweight="bold")
plt.title(" Boxplot illustrating Aspiration by Horsepower", fontsize=12, fontweight="bold")
plt.xticks(rotation=60, fontsize=12)
plt.rcParams["xtick.labelsize"]=30

# %% [markdown]
# **Observations:**
# - Standard autos have less horsepower compared to turbo autos.
# - Data are outlier in standard autos.
# - Two standard autos have too much horsepower.
# - Most of standard autos have 75 horsepower.
# - Number of turbo autos are too much less rather than standard autos.

# %% [markdown]
# **Question 22:** Which type of autos have the highest peak rpm on the basis of drive wheels?

# %%
plt.figure(figsize=(9,5))
sns.boxplot(data=Ap_df, x='drive-wheels', y="peak-rpm", orient="vertical", color=plot_color)
plt.xlabel("Drive Wheels", fontsize=12, fontweight="bold")
plt.ylabel("Peak RPM", fontsize=12, fontweight="bold")
plt.title(" Boxplot illustrating Peak RPM by Drive Wheels", fontsize=12, fontweight="bold")
# Out:
# Text(0.5, 1.0, ' Boxplot illustrating Peak RPM by Drive Wheels')

# %% [markdown]
# **Observations:**
# - Front wheel drive autos have the highest peak rpm.
# - Four wheel drive autos have the lowest peak rpm.
# - There are skewed data in the four wheel drive and rear wheel drive.

# %% [markdown]
# **Question 23:** Do fuel type have effect on price of the autos?

# %%
sns.violinplot(data=Ap_df, x="fuel-type", y="price", palette="gnuplot")
plt.xlabel("Fuel Type", fontsize=13, fontweight="bold")
plt.ylabel("Price", fontsize=13, fontweight="bold")
plt.title("Violin Plot illustrating Fuel Type by Price", fontsize=13, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Violin Plot illustrating Fuel Type by Price')

# %% [markdown]
# **Observations:**
#
# - Diesel fuel type autos are more expensive body style compared to Gas fuel type autos.
# - In the meanwhile, the distribution of price is more vary in the gas fuel type.
# - Price distribution in gas fuel type is more vary with right skewness.
# - More autos in diesel fuel type are priced about 10000 unit of currency.

# %% [markdown]
# **Question 24:**
# - What is the relationship between price and normalized losses?

# %%
Ap_df.plot(kind="scatter", x="normalized-losses", y="price", figsize=(10,5), grid=True, fontsize=13, color="maroon")
plt.xlabel("Normalized Losses", fontsize=13, fontweight="bold")
plt.ylabel("Price", fontsize=13, fontweight="bold")
plt.title(" Regplot illustrating Price by Normalized Losses", fontsize=13, fontweight="bold")
# Out:
# Text(0.5, 1.0, ' Regplot illustrating Price by Normalized Losses')

# %% [markdown]
# **Observation:**
# - The relationship between price and normalized losses is hetroskedastic; in the begining the correlation is high, in the middle is mild and in the end even there haven't seen any correlation.

# %% [markdown]
# **Question 25:**
# - What is the relationship between price and city mileage?

# %%
Ap_df.plot(kind="scatter", x="city-mpg", y="sprice",figsize=(10,5), fontsize=10, color="red" )
plt.xlabel("City Mileage", fontsize=12, fontweight="bold")
plt.ylabel("Price", fontsize=12, fontweight="bold")
plt.title("scatter Plot illustrating Price City Mileage", fontsize=12, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'scatter Plot illustrating Price City Mileage')

# %% [markdown]
# **Observation:**
# - There is a negative correlation between city mileage and price. when city miliage goes up the price goes down and vise versa.

# %% [markdown]
# **Question 26:**  Which body type of autos are more desirable by customers?

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=Ap_df, x='body-style', y="price", orient="vertical", color="springgreen")
plt.xlabel("Body Style", fontsize=12, fontweight="bold")
plt.ylabel("Price", fontsize=12, fontweight="bold")
plt.title(" Boxplot illustrating Price by Number of Body Style", fontsize=12, fontweight="bold")
plt.xticks(rotation=70, fontsize=11)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text xticklabel objects>)

# %% [markdown]
# **Observations:**
# - Hardtop body style autos are the most expensive which the median value is 20000.
# - Hatchback body style autos are the cheapest outos among all other autos.
# - Some outliers are in Wagon, Sedan and Hatchback body style.

# %% [markdown]
# **Question 27:**  What is the relationship between price and highway mileage?

# %%
Ap_df.plot(kind="scatter", x="price", y="highway-mpg",figsize=(10,5), fontsize=10, color="b" )
plt.xlabel("Price", fontsize=12, fontweight="bold")
plt.ylabel("Highway Mileage", fontsize=12, fontweight="bold")
plt.title("scatter Plot illustrating Price Highway Mileage", fontsize=12, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'scatter Plot illustrating Price Highway Mileage')

# %% [markdown]
# **Observation:**
# - Price is negatively correlated with highway mileage; as highway mileage increases, the price decreases.

# %% [markdown]
# **Question 28:** How is the variation of peak rpm with horsepower?

# %%
Ap_df.plot(kind="hexbin", x="peak-rpm", y="horsepower", figsize=(10,5), gridsize=25, color="fuchsia", fontsize=10)
plt.xlabel("Peak RPM", fontsize=12, fontweight="bold")
plt.ylabel("Horsepower", fontsize=12, fontweight="bold")
plt.title("Hexplot Plot illustrating variation of Peak RPM with Horsepower", fontsize=12, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Hexplot Plot illustrating variation of Peak RPM with Horsepower')

# %% [markdown]
# **Observations:**
# - While autos have about 5200 and 5500 peak rpm, their horsepower is about 65.
# - Autos having 4800 peak rpm ranged in somewhere 75 horsepower.

# %% [markdown]
# **Question 29:** How are the relationship between numerical characteristics(wheel base, bore, normalized losses and compression ratio)?

# %%
#fig,ax = plt.subplots(figsize=(10,5), ncols=1, nrows=1)
sns.pairplot(Ap_df[["wheel-base","bore", "engine-size","compression-ratio"]],size=2.5,diag_kind="hist")

# %% [markdown]
# **Observations:**
# - Wheel base and Bore positively correlated but this correlation is not very strong.
# - Wheel base and engine size is also positively correlated.
# - Wheel base and compression ratio is not correlated, they are independent.
# - There is a weak correaltion between Bore and engine size.
# - No correlation is between bore and compression ratio.
# - No correlation is between engine size and compression ratio.

# %% [markdown]
# **Question 30:** Which body style autos are in first priority of customers regarding number of doors?

# %%
with sns.axes_style("ticks"):
    p = sns.factorplot("num-of-doors",aspect=2,  data=Ap_df, kind="count", hue="body-style", legend=True)
    p.set_ylabels("Count", fontsize=12 )

# %% [markdown]
# **Observations:**
# - Number of Sedan body style autos are more than any other body style in four doors category.
# - Hatchback body style autos are more in two doors category.
# - There are no any convertible and Hardtop autos having four doors.

# %%
sns.pairplot(Ap_df[["horsepower","city-mpg", "highway-mpg","curb-weight"]],size=2.5, 
             diag_kind="kde")

# %% [markdown]
# **Observations:**
# - Horsepower is negatively correlated with city mileage.
# - There is a negative correaltion between horsepower and highway mileage.
# - Horsepower is highly positively correlated with curb weight.
# - A high correlation is there bewtween ciyt mileage and highway mileage.
# - City mileage and curb weight is negatively correlated.
# - Highway mileage also have negative correlation with curb weight.

# %% [markdown]
# **Question 31** What is the relationship between price and curb weight of outos?

# %%
plt.figure(figsize=(10,5))
sns.regplot(data=Ap_df, x="curb-weight", y="price", color="fuchsia")
plt.xlabel("Curb Weight", fontsize=13, fontweight="bold")
plt.ylabel("Price", fontsize=13, fontweight="bold")
plt.title(" Regplot illustrating Price by Curb weight", fontsize=13, fontweight="bold")
# Out:
# Text(0.5, 1.0, ' Regplot illustrating Price by Curb weight')

# %% [markdown]
# **Observations:**
# - As inference that is given from above scatter plot, there is a positive correlation between price and curb weight.

# %% [markdown]
# **Question 32:**Which breathing type of autos have more curb weight?

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=Ap_df,x="aspiration",y="curb-weight")
plt.xlabel("Breathing", fontsize=13, fontweight="bold")
plt.ylabel("Curb Weight", fontsize=13, fontweight="bold")
plt.title(" Boxplot illustrating Breathing by Curb weight", fontsize=13, fontweight="bold")
# Out:
# Text(0.5, 1.0, ' Boxplot illustrating Breathing by Curb weight')

# %% [markdown]
# **Observations:**
# - Curb weight of Turbo autos are heavier than atandard autos.
# - Curb weight of turbo autos are normally distributed.
# - Outlier data also exist in curb weight of standard outos.

# %% [markdown]
# **Question 33:** What are the conditions of city and highway mileages in respect to brands?

# %%
Ap_df.groupby(["make"])["city-mpg"].mean().plot(kind="line", fontsize=13, figsize=(5,3), color="green")
Ap_df.groupby(["make"])["highway-mpg"].mean().plot(kind="line", fontsize=13, figsize=(13,7), color="red")
#Ap_df.groupby(["make"])["height"].mean().plot(kind="bar", fontsize=13, figsize=(13,7), color="blue")
plt.xlabel("Make", fontsize=12, fontweight="bold")
plt.ylabel("Value", fontsize=12, fontweight="bold")
plt.title(" Stacked Line Chart illustrating city and highway Mileage of Each Brand", fontsize=12, fontweight="bold")
plt.legend()

# %% [markdown]
# **Observations:**
# - As the line charts illustrate, city and highway mileage are different in different brands but city mileage is greater than highway mileage and also they are atationary.

# %% [markdown]
# <a id=section13></a>
# #### 13. Multivariate Analysis

# %% [markdown]
# **Question 34:** How is the relationship between city and highway mileages in respect to Brands?

# %%
plt.figure(figsize=(13,7))
sns.scatterplot(data=Ap_df, x="city-mpg", y="highway-mpg", hue="make")
plt.xlabel("City Mileage", fontsize=12, fontweight="bold")
plt.ylabel("Highway Mileage", fontsize=12, fontweight="bold")
plt.title(" Scatterplot illustrating variation city & highway mileage with brand", fontsize=12, fontweight="bold")
plt.legend(ncol=2, fontsize=12,loc="lower right", title="Brand")

# %% [markdown]
# **Observations:**
# - There is a high positive correlation between city mileage and highway mileage in all brands.
# - As the chart illustrates, there are alot more Toyota brands.

# %% [markdown]
# **Question 35:** Which type of engine is the costliest auto in respect to fuel type?

# %%
with sns.axes_style(style="white"):
    m = sns.factorplot("engine-type", "price","fuel-type",  data=Ap_df, kind="box", aspect=2)
    m.set_axis_labels("engine-type", "price")
plt.figure(figsize=(10,5))
# Out:
# C:\Users\ZeytoonCo\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# **Observations:**
# - Engine type of OHCV autos with gas fuel type are the costliest autos.
# - Among the diesel fuel type, engine type of OHC is the costliest autos.

# %% [markdown]
# **Question 36:** Are there any correlation between price and curb weight, length, width and height in respect to aspiration?

# %%
plt.figure(figsize=(13,7))
sns.pairplot(Ap_df,size=4, aspect=1,  x_vars=['curb-weight','length','width','height'], y_vars=["price"], 
             kind='scatter', hue='aspiration')

# %% [markdown]
# **Observations:**
# - Price is highly correlated with curb weight, length,and width attributes in both aspirations.
# - As it is observed, standard and turbo segments are not separated because too many overlapings are there.
# - There is no correlation between price and height.

# %% [markdown]
# **Question 37:** Are there any correlation between wheel base, bore, and engin sizein respect to body style?

# %%
g = Ap_df[["wheel-base","bore", "engine-size","body-style"]]
sns.pairplot(g, hue="body-style", size=2.5, diag_kind="kde")
#plt.title("Pair Plot illustrating the ralationship between four variables", fontsize=12, fontweight="bold")

# %% [markdown]
# **Observations:**
# - Wheel base has positive correlation withe bore and engine size.
# - Bore and engine size also have positive correalation.
# - Sedan body style is more vesible every pair plot.

# %% [markdown]
# **Question 38:** How is the relationshipe between all numeric attributes of autos?

# %%
plt.figure(figsize=(13,6))
Ap_df_corr = Ap_df.corr()
sns.heatmap(Ap_df_corr, annot=True, fmt='.2f', linewidths=1)

# %% [markdown]
# **Observations:**
# - Wheel base, length, width, curb weight, engine size, bore, horsepower and price highly negatively correlated with city and highway mileage.
# - Wheel base and curb weight positively correlated with length and width of autos.
# - Normalized losses, length, weight, width, curb weight, engine size, bore and horsepower highly positively correlated with price of autos.
# - Highway mileage, city mileage, and symboling have high negative correlation with price of the autos.

# %% [markdown]
# <a id=section14></a>
# #### 14. Conlusion
# By conducting this project, I have gove through automobile dataset and after doing profiling, data processiing and exploratory data analysis(EDA), the following points extracted:
# - Only 1.5% of the autos are more safe.
# - Most of the autos have normalized losses of around 100 and 160.
# - Three top brands are Toyota(16.1%), Nissan (9.05%) and Mitsubish(6.53%).
# - About 180 autos are using gas.
# - About 120 autos have four doors.
# - OHC engine size autos are more desirable.
# - 81.4% of autos breathing on standard type.
# - Sedan body style autos are a favorable body style for most of the people.
# - Front wheel drive cars are the most desirable cars for customers.
# - Four cylinder autos are the most desirable.
# - Most of autos are pricing around USD 10,000.
# - The most costlier auto is jaguar with around USD 35000 and the cheapest auto is Chevrolet with around USD 5000.
# - Hardtop body style is the most expensive auto.
# - City and Highway mileage have negative correlation with price.
# - Bore and engine size have positive correlation.
# - Most of Sedan body stye have four doors.
# - Most of Hatchback autos have two door.
# - Price and curb wight have high negative correlation.
# - Turbo autos are more heavy than standard autos.
# - City and highway mileage are stationary for all brands.
# - Normalized losses, length, weight, width, curb weight, engine size, bore and horsepower are the attributes which have positive affect on price of auto.
# - Highway mileage, city mileage, and symboling have high negative impact on price of autos.
# - **Summary:** Fuel type, Number of doors, Body style, wheel drive, Number of cylinders, engine size and price attributes are the most important factors affect sales amount.

# %% [markdown]
# <a id=section15></a>
# #### 15. Actionable Insights
# Actionable insights aiming to imporove sales after analyzing the dataset are as follows:
# 1. Gas fuel type are the best seller so autos with gas fuel type should be more focused.
# 2. Customers are willing to buy four doors more so this type of autos should be in concentration.
# 3. Sedar body style are very desirable so the company shoul supply more Sedan body style.
# 4. Analysis shows more sales for Front wheel drive with four cylinders, so the company is expected to invest more on front wheel drive with four cylinders.
# 5. The favorite engine size for customers is OHC with standard aspiration, so the sellers shoul have more such cars in their shops.
